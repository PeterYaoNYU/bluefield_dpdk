# %%
import matplotlib.pyplot as plt
import statistics
# Function to process data between the first and second "*******************New Run*******************" markers
def process_data_between_markers(lines):
    data = {"time": [], "false_positives": []}
    marker_count = 0
    interval = 1000  # X-axis interval for heartbeat messages
    heartbeat_count = 0

    for line in lines:
        if line.strip() == "*******************New Run*******************":
            marker_count += 1
            if marker_count == 2:
                break
        elif marker_count == 1 and line.strip().startswith("false_positives: "):
            try:
                cnt = int(line.strip().split(": ")[1])
                data["false_positives"].append(cnt)
                heartbeat_count += 1
                data["time"].append(interval * heartbeat_count)
            except (ValueError, IndexError):
                pass
            
    print(statistics.mean(data["false_positives"])

    return data

# Read data from the file
def read_data_from_file(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()
    return lines

# Main function to plot the line chart
def plot_line_chart(data):
    plt.figure(figsize=(10, 6))
    plt.plot(data["time"], data["false_positives"], marker='o')
    plt.xlabel('Time (Heartbeat Messages)')
    plt.ylabel('False Positives (Number)')
    plt.title('Bertier False Positive Count (every 1000 heartbeats)')
    plt.grid(True)
    
    # Set the y-axis limits to (0, 1000)
    plt.ylim(0, 60)
    plt.show()

if __name__ == "__main__":
    file_path = "general_stats.txt"  # Replace with the path to your text file
    lines = read_data_from_file(file_path)
    data = process_data_between_markers(lines)

    print(data["false_positives"])
    print("Processed Data:", data)
    plot_line_chart(data)
# Out:
# Processed Data: {'time': [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000, 13000, 14000, 15000, 16000, 17000, 18000, 19000, 20000, 21000, 22000, 23000, 24000, 25000, 26000, 27000, 28000, 29000, 30000, 31000, 32000, 33000, 34000, 35000, 36000, 37000, 38000, 39000, 40000, 41000, 42000, 43000, 44000, 45000, 46000, 47000, 48000, 49000, 50000, 51000, 52000, 53000, 54000, 55000, 56000, 57000, 58000, 59000, 60000, 61000, 62000, 63000, 64000, 65000, 66000], 'false_positives': [6, 7, 14, 11, 6, 11, 14, 6, 10, 6, 0, 0, 1, 14, 8, 11, 11, 6, 13, 9, 13, 7, 18, 4, 7, 10, 9, 13, 2, 8, 7, 11, 10, 0, 2, 1, 7, 8, 10, 9, 0, 0, 1, 8, 11, 9, 14, 7, 6, 14, 1, 0, 14, 7, 12, 9, 8, 11, 9, 8, 6, 0, 1, 0, 14, 8]}

# %%
import matplotlib.pyplot as plt
import statistics
# Function to process data between the first and second "*******************New Run*******************" markers
def process_data_between_markers(lines):
    data = {"time": [], "false_positives": []}
    marker_count = 0
    interval = 1000  # X-axis interval for heartbeat messages
    heartbeat_count = 0

    for line in lines:
        if line.strip() == "*******************New Run*******************":
            marker_count += 1
            if marker_count == 3:
                break
        elif marker_count == 2 and line.strip().startswith("false_positives: "):
            try:
                cnt = int(line.strip().split(": ")[1])
                data["false_positives"].append(cnt)
                heartbeat_count += 1
                data["time"].append(interval * heartbeat_count)
            except (ValueError, IndexError):
                pass

    return data

# Read data from the file
def read_data_from_file(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()
    return lines

# Main function to plot the line chart
def plot_line_chart(data):
    plt.figure(figsize=(10, 6))
    plt.plot(data["time"], data["false_positives"], marker='o')
    plt.xlabel('Time (Heartbeat Messages)')
    plt.ylabel('False Positives (Number)')
    plt.title('Bertier False Positive Count (every 1000 heartbeats, traces from log1)')
    plt.grid(True)
    
    # Set the y-axis limits to (0, 1000)
    plt.ylim(0, 60)
    plt.show()

if __name__ == "__main__":
    file_path = "general_stats.txt"  # Replace with the path to your text file
    lines = read_data_from_file(file_path)
    data = process_data_between_markers(lines)
    
    print(statistics.mean(data["false_positives"]))
    print("Processed Data:", data)
    print(data["false_positives"])
    plot_line_chart(data)
# Out:
# 14.25
# Processed Data: {'time': [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 11000, 12000], 'false_positives': [9, 12, 22, 14, 8, 21, 9, 11, 16, 18, 8, 23]}
# [9, 12, 22, 14, 8, 21, 9, 11, 16, 18, 8, 23]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 statistics.mean([9, 12, 22, 14, 8, 21, 9, 11, 16, 18, 8, 23])
#
# NameError: name 'statistics' is not defined
